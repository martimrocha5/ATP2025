# %%
#Neste exercício, as funções definidas anteriormente na aula podiam ter sido utilizadas para a execução do mesmo, no entanto, e por motivos de logística, decidi refazer as mesmas para poder ser possível executar o programa.
lista=[]
import random

def criaLista(N):
    global lista
    lista=[]
    i = 1
    while i <= N:
        i += 1
        lista.append(random.randint(1,100))
    return lista

def leLista(N):
    global lista
    lista=[] 
    i = 0
    while i < N:
        i += 1
        lista.append(int(input("introduza um número"))) 
    return lista

def somaLista(N):
    global lista
    soma=0
    for i in N:
        soma += i    
    return (soma)

def mediaLista(N):
    global lista
    soma = 0
    for i in N:
        soma += i             
    return (soma/len(lista))

def maiorLista(N):
    global lista
    maior=N[0]
    for i in N:
        if i>maior:
            maior=i
    return maior
        
def menorLista(N):
    global lista
    menor=N[0]
    for i in N:
        if i<menor:
            menor=i
    return menor

def estaOrdenadaC(N):
    global lista
    for i in range(len(N) - 1):
        if N[i] > N[i + 1]:
            return "Não"
    return "Sim"

def estaOrdenadaD(N):
    global lista
    for i in range(len(N) - 1):
        if N[i] < N[i + 1]:
            return "Não"
    return "Sim"

def indiceDe(N, elem):
    for i in range(len(lista)):
        if lista[i] == elem:
            return i
    return -1


modo=10

while modo != 0:
    modo = int(input("Qual opção deseja efetuar:\n(1): Criar lista aleatoriamente \n(2): Ler lista \n(3): Soma \n(4): Média \n(5): Maior \n(6): Menor \n(7): Lista ordenada de forma crescente \n(8): Lista ordenada de forma decrescente \n(9): Procura um elemento \n(0): Sair"))
    
    if modo == 0:
        break

    if modo == 1:

        print(criaLista(int(input("Intoduza o total de números que quer na lista"))))

    elif modo == 2:
        
        print(leLista(int(input("Intoduza o total de números que quer na lista"))))
    
    elif modo == 3:
        
        print(somaLista(lista))

    elif modo == 4:
        
        print(mediaLista(lista))

    elif modo == 5:
                 
        print(maiorLista(lista))

    elif modo == 6:
        
        print(menorLista(lista))

    elif modo == 7:

        resultado=estaOrdenadaC(lista)
        print(resultado)

    elif modo == 8:

        resultado2=estaOrdenadaD(lista)
        print(resultado2)

    elif modo == 9:

        print(lista)
        print(indiceDe(lista,int(input("Que número seja procurar?"))))
    
    else:
        print("Número inválido, digite um valor novamente")

print(f"A tua Lista final é:{lista}")
print("Obrigado por utilizar a aplicação!")
# Out:
# []
# -1
# [67, 52, 29, 18, 22, 74]
# [67, 52, 29, 18, 22, 74]
# -1
# A tua Lista final é:[67, 52, 29, 18, 22, 74]
# Obrigado por utilizar a aplicação!
